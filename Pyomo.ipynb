# %% [markdown]
# ### Minimization probelms

# %% [markdown]
# ***Notes example***

# %%
from pyomo.environ import *
from pyomo.opt import *

model=ConcreteModel()

model.x=Var(within=NonNegativeReals)
model.y=Var(within=NonNegativeReals)

model.obj=Objective(expr=2*model.x+3*model.y, sense=maximize)

model.con1=Constraint(expr=2*model.x+model.y<=10)
model.con2=Constraint(expr=5*model.x+model.y<=15)

solver=SolverFactory('glpk')
results=solver.solve(model)
print(results)

print('the value of x is', value(model.x))
print('the value of y is', value(model.y))
print('the maximum is', value(model.obj))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 30.0
#   Upper bound: 30.0
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 3
#   Number of nonzeros: 5
#   Sense: maximize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.051305294036865234
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# the value of x is 0.0
# the value of y is 10.0
# the maximum is 30.0

# %% [markdown]
# ***5.1-6***

# %%
from pyomo.environ import *
from pyomo.opt import *

model = ConcreteModel()

model.x = Var(within=NonNegativeReals)
model.y = Var(within=NonNegativeReals)

model.obj = Objective(expr=8*model.x+5*model.y, sense=minimize)

model.con1 = Constraint(expr=-3*model.x+2*model.y <= 30)
model.con2 = Constraint(expr=2*model.x+model.y >= 50)
model.con3 = Constraint(expr=model.x+model.y >= 30)

solver = SolverFactory("glpk")
results = solver.solve(model)
print(results)

print("The value of x is", value(model.x))
print("The value of y is", value(model.y))
print("The minimum is", value(model.obj))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 210.0
#   Upper bound: 210.0
#   Number of objectives: 1
#   Number of constraints: 4
#   Number of variables: 3
#   Number of nonzeros: 7
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.043940067291259766
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# The value of x is 20.0
# The value of y is 10.0
# The minimum is 210.0

# %% [markdown]
# ### Transportation problems

# %% [markdown]
# ***Notes example***

# %%
from pyomo.environ import *
from pyomo.opt import *

model = ConcreteModel()

model.c1 = Var(within=NonNegativeReals)
model.c2 = Var(within=NonNegativeReals)
model.d1 = Var(within=NonNegativeReals)
model.d2 = Var(within=NonNegativeReals)

model.obj = Objective(expr=10*model.c1+5*model.c2+8*model.d1+3*model.d2, sense=minimize)

model.con1 = Constraint(expr=model.c1+model.c2 <= 90)
model.con2 = Constraint(expr=model.d1+model.d2 <= 50)
model.con3 = Constraint(expr=model.c1+model.d1 >= 80)
model.con4 = Constraint(expr=model.c2+model.d2 >= 60)

solver = SolverFactory("glpk")
results = solver.solve(model)
print(results)

print("The value of c1 is", value(model.c1))
print("The value of c2 is", value(model.c2))
print("The value of d1 is", value(model.d1))
print("The value of d2 is", value(model.d2))

print("The minimum is", value(model.obj))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 1000.0
#   Upper bound: 1000.0
#   Number of objectives: 1
#   Number of constraints: 5
#   Number of variables: 5
#   Number of nonzeros: 9
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.0434877872467041
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# The value of c1 is 80.0
# The value of c2 is 10.0
# The value of d1 is 0.0
# The value of d2 is 50.0
# The minimum is 1000.0

# %% [markdown]
# Still gotta figure out when to use **>=/<=** or **==**

# %%
from pyomo.environ import *
from pyomo.opt import *

model = ConcreteModel()

model.c1 = Var(within=NonNegativeReals)
model.c2 = Var(within=NonNegativeReals)
model.d1 = Var(within=NonNegativeReals)
model.d2 = Var(within=NonNegativeReals)

model.obj = Objective(expr=10*model.c1+5*model.c2+8*model.d1+3*model.d2, sense=minimize)

model.con1 = Constraint(expr=model.c1+model.c2 == 90)
model.con2 = Constraint(expr=model.d1+model.d2 == 50)
model.con3 = Constraint(expr=model.c1+model.d1 == 80)
model.con4 = Constraint(expr=model.c2+model.d2 == 60)

solver = SolverFactory("glpk")
results = solver.solve(model)
print(results)

print("The value of c1 is", value(model.c1))
print("The value of c2 is", value(model.c2))
print("The value of d1 is", value(model.d1))
print("The value of d2 is", value(model.d2))

print("The minimum is", value(model.obj))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 1000.0
#   Upper bound: 1000.0
#   Number of objectives: 1
#   Number of constraints: 5
#   Number of variables: 5
#   Number of nonzeros: 9
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.044184207916259766
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# The value of c1 is 30.0
# The value of c2 is 60.0
# The value of d1 is 50.0
# The value of d2 is 0.0
# The minimum is 1000.0

# %% [markdown]
# ***Table 8.2***

# %%
from pyomo.environ import *
from pyomo.opt import *

model = ConcreteModel()

#Introducing the variables
model.x1a = Var(within=NonNegativeIntegers)
model.x1b = Var(within=NonNegativeIntegers)
model.x1c = Var(within=NonNegativeIntegers)
model.x1d = Var(within=NonNegativeIntegers)
model.x2a = Var(within=NonNegativeIntegers)
model.x2b = Var(within=NonNegativeIntegers)
model.x2c = Var(within=NonNegativeIntegers)
model.x2d = Var(within=NonNegativeIntegers)
model.x3a = Var(within=NonNegativeIntegers)
model.x3b = Var(within=NonNegativeIntegers)
model.x3c = Var(within=NonNegativeIntegers)
model.x3d = Var(within=NonNegativeIntegers)

#Introducing the objective function
model.obj = Objective(expr=464*model.x1a + 513*model.x1b + 654*model.x1c + 867*model.x1d + 352*model.x2a + 416*model.x2b + 690*model.x2c + 791*model.x2d + 995*model.x3a +682*model.x3b + 388*model.x3c + 685*model.x3d, sense = minimize)

#Introducing the restrictions 
model.con1 = Constraint(expr=model.x1a + model.x1b + model.x1c + model.x1d == 75)
model.con2 = Constraint(expr=model.x2a + model.x2b + model.x2c + model.x2d == 125)
model.con3 = Constraint(expr= model.x3a + model.x3b + model.x3c + model.x3d == 100)
model.con4 = Constraint(expr= model.x1a + model.x2a + model.x3a == 80)
model.con5 = Constraint(expr= model.x1b + model.x2b + model.x3b == 65)
model.con6 = Constraint(expr= model.x1c + model.x2c + model.x3c == 70)
model.con7 = Constraint(expr= model.x1d + model.x2d + model.x3d == 85)

#Solving the equation
solver = SolverFactory("glpk")
results = solver.solve(model)
print("The value of x1a is: ", value(model.x1a))
print("The value of x1b is: ", value(model.x1b))
print("The value of x1c is: ", value(model.x1c))
print("The value of x1d is: ", value(model.x1d))
print("The value of x2a is: ", value(model.x2a))
print("The value of x2b is: ", value(model.x2b))
print("The value of x2c is: ", value(model.x2c))
print("The value of x2d is: ", value(model.x2d))
print("The value of x3a is: ", value(model.x3a))
print("The value of x3b is: ", value(model.x3b))
print("The value of x3c is: ", value(model.x3c))
print("The value of x3d is: ", value(model.x3d))
print("The minimum cost is", value(model.obj))
# Out:
# The value of x1a is:  0.0
# The value of x1b is:  20.0
# The value of x1c is:  0.0
# The value of x1d is:  55.0
# The value of x2a is:  80.0
# The value of x2b is:  45.0
# The value of x2c is:  0.0
# The value of x2d is:  0.0
# The value of x3a is:  0.0
# The value of x3b is:  0.0
# The value of x3c is:  70.0
# The value of x3d is:  30.0
# The minimum cost is 152535.0

# %% [markdown]
# ***8.2-7***

# %%
from pyomo.environ import *
from pyomo.opt import *

model = ConcreteModel()

#Introducing the variables
model.x1a = Var(within=NonNegativeIntegers)
model.x1b = Var(within=NonNegativeIntegers)
model.x1c = Var(within=NonNegativeIntegers)
model.x1d = Var(within=NonNegativeIntegers)
model.x2a = Var(within=NonNegativeIntegers)
model.x2b = Var(within=NonNegativeIntegers)
model.x2c = Var(within=NonNegativeIntegers)
model.x2d = Var(within=NonNegativeIntegers)
model.x3a = Var(within=NonNegativeIntegers)
model.x3b = Var(within=NonNegativeIntegers)
model.x3c = Var(within=NonNegativeIntegers)
model.x3d = Var(within=NonNegativeIntegers)

#Introducing the objective function
model.obj = Objective(expr=3*model.x1a + 7*model.x1b + 6*model.x1c + 4*model.x1d + 2*model.x2a + 4*model.x2b + 3*model.x2c + 2*model.x2d + 4*model.x3a +3*model.x3b + 8*model.x3c + 5*model.x3d, sense = minimize)

#Introducing the restrictions 
model.con1 = Constraint(expr=model.x1a + model.x1b + model.x1c + model.x1d == 5)
model.con2 = Constraint(expr=model.x2a + model.x2b + model.x2c + model.x2d == 2)
model.con3 = Constraint(expr= model.x3a + model.x3b + model.x3c + model.x3d == 3)
model.con4 = Constraint(expr= model.x1a + model.x2a + model.x3a == 3)
model.con5 = Constraint(expr= model.x1b + model.x2b + model.x3b == 3)
model.con6 = Constraint(expr= model.x1c + model.x2c + model.x3c == 2)
model.con7 = Constraint(expr= model.x1d + model.x2d + model.x3d == 2)

#Solving the equation
solver = SolverFactory("glpk")
results = solver.solve(model)
print("The value of x1a is: ", value(model.x1a))
print("The value of x1b is: ", value(model.x1b))
print("The value of x1c is: ", value(model.x1c))
print("The value of x1d is: ", value(model.x1d))
print("The value of x2a is: ", value(model.x2a))
print("The value of x2b is: ", value(model.x2b))
print("The value of x2c is: ", value(model.x2c))
print("The value of x2d is: ", value(model.x2d))
print("The value of x3a is: ", value(model.x3a))
print("The value of x3b is: ", value(model.x3b))
print("The value of x3c is: ", value(model.x3c))
print("The value of x3d is: ", value(model.x3d))
print("The minimum cost is", value(model.obj))
# Out:
# The value of x1a is:  3.0
# The value of x1b is:  0.0
# The value of x1c is:  0.0
# The value of x1d is:  2.0
# The value of x2a is:  0.0
# The value of x2b is:  0.0
# The value of x2c is:  2.0
# The value of x2d is:  0.0
# The value of x3a is:  0.0
# The value of x3b is:  3.0
# The value of x3c is:  0.0
# The value of x3d is:  0.0
# The minimum cost is 32.0

# %% [markdown]
# ### Asignation problems

# %% [markdown]
# ***8.3-2***

# %%
from pyomo.environ import*
from pyomo.opt import*
model=ConcreteModel()


model.x1a=Var(within=Binary)
model.x1b=Var(within=Binary)
model.x1c=Var(within=Binary)
model.x1d=Var(within=Binary)
model.x2a=Var(within=Binary)
model.x2b=Var(within=Binary)
model.x2c=Var(within=Binary)
model.x2d=Var(within=Binary)
model.x3a=Var(within=Binary)
model.x3b=Var(within=Binary)
model.x3c=Var(within=Binary)
model.x3d=Var(within=Binary)
model.x4a=Var(within=Binary)
model.x4b=Var(within=Binary)
model.x4c=Var(within=Binary)
model.x4d=Var(within=Binary)

model.obj=Objective(expr=5*model.x1a+4*model.x1b+6*model.x1c+5*model.x1d+
                    6*model.x2a+6*model.x2b+7*model.x2c+5*model.x2d+
                    7*model.x3a+5*model.x3b+7*model.x3c+6*model.x3d+
                    5*model.x4a+4*model.x4b+6*model.x4c+6*model.x4d,sense=minimize)

model.con1=Constraint(expr=model.x1a+model.x1b+model.x1c+model.x1d==1)
model.con2=Constraint(expr=model.x2a+model.x2b+model.x2c+model.x2d==1)
model.con3=Constraint(expr=model.x3a+model.x3b+model.x3c+model.x3d==1)
model.con4=Constraint(expr=model.x4a+model.x4b+model.x4c+model.x4d==1)

model.con5=Constraint(expr=model.x1a+model.x2a+model.x3a+model.x4a==1)
model.con6=Constraint(expr=model.x1b+model.x2b+model.x3b+model.x4b==1)
model.con7=Constraint(expr=model.x1c+model.x2c+model.x3c+model.x4c==1)
model.con8=Constraint(expr=model.x1d+model.x2d+model.x3d+model.x4d==1)

solver=SolverFactory('glpk')
results=solver.solve(model)
print(results)


print('The value of x1A is', value(model.x1a))
print('The value of x1B is', value(model.x1b))
print('The value of x1C is', value(model.x1c))
print('The value of x1D is', value(model.x1d))
print('The value of x2A is', value(model.x2a))
print('The value of x2B is', value(model.x2b))
print('The value of x2C is', value(model.x2c))
print('The value of x2D is', value(model.x2d))
print('The value of x3A is', value(model.x3a))
print('The value of x3B is', value(model.x3b))
print('The value of x3C is', value(model.x3c))
print('The value of x3D is', value(model.x3d))
print('The value of x4A is', value(model.x4a))
print('The value of x4B is', value(model.x4b))
print('The value of x4C is', value(model.x4c))
print('The value of x4D is', value(model.x4d))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 21.0
#   Upper bound: 21.0
#   Number of objectives: 1
#   Number of constraints: 9
#   Number of variables: 17
#   Number of nonzeros: 33
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.048642873764038086
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# The value of x1A is 1.0
# The value of x1B is 0.0
# The value of x1C is 0.0
# The value of x1D is 0.0
# The value of x2A is 0.0
# The value of x2B is 0.0
# The value of x2C is 0.0
# The value of x2D is 1.0
# The value of x3A is 0.0
# The value of x3B is 0.0
# The value of x3C is 1.0
# The value of x3D is 0.0
# The value of x4A is 0.0
# The value of x4B is 1.0
# The value of x4C is 0.0
# The value of x4D is 0.0

# %% [markdown]
# ### Shortest path problem

# %%
from pyomo.environ import*
from pyomo.opt import*
model=ConcreteModel()


model.xoa=Var(within=Binary)
model.xob=Var(within=Binary)
model.xoc=Var(within=Binary)
model.xab=Var(within=Binary)
model.xad=Var(within=Binary)
model.xcb=Var(within=Binary)
model.xbd=Var(within=Binary)
model.xbe=Var(within=Binary)
model.xce=Var(within=Binary)
model.xde=Var(within=Binary)
model.xdt=Var(within=Binary)
model.xet=Var(within=Binary)


model.obj=Objective(expr=2*model.xoa+5*model.xob+4*model.xoc+2*model.xab+
                    7*model.xad+1*model.xcb+4*model.xbd+3*model.xbe+
                    4*model.xce+1*model.xde+5*model.xdt+7*model.xet,sense=minimize)

model.con1=Constraint(expr=model.xoa+model.xob+model.xoc==1)
model.con2=Constraint(expr=model.xoa==model.xab+model.xad)
model.con3=Constraint(expr=model.xab+model.xob+model.xcb==model.xbd+model.xbe)
model.con4=Constraint(expr=model.xoc==model.xcb+model.xce)
model.con5=Constraint(expr=model.xad+model.xbd==model.xdt+model.xde)
model.con6=Constraint(expr=model.xde+model.xbe+model.xce==model.xet)
model.con7=Constraint(expr=model.xdt+model.xet==1)


solver=SolverFactory('glpk')
results=solver.solve(model)
print(results)


print('The value of xoa is', value(model.xoa))
print('The value of xob is', value(model.xob))
print('The value of xoc is', value(model.xoc))
print('The value of xab is', value(model.xab))
print('The value of xad is', value(model.xad))
print('The value of xcb is', value(model.xcb))
print('The value of xbd is', value(model.xbd))
print('The value of xbe is', value(model.xbe))
print('The value of xce is', value(model.xce))
print('The value of xde is', value(model.xde))
print('The value of xdt is', value(model.xdt))
print('The value of xet is', value(model.xet))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 13.0
#   Upper bound: 13.0
#   Number of objectives: 1
#   Number of constraints: 8
#   Number of variables: 13
#   Number of nonzeros: 25
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.03854823112487793
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# The value of xoa is 1.0
# The value of xob is 0.0
# The value of xoc is 0.0
# The value of xab is 1.0
# The value of xad is 0.0
# The value of xcb is 0.0
# The value of xbd is 1.0
# The value of xbe is 0.0
# The value of xce is 0.0
# The value of xde is 0.0
# The value of xdt is 1.0
# The value of xet is 0.0

# %% [markdown]
# ### Hospital problems

# %% [markdown]
# ***Slides***

# %%
from pyomo.environ import*
from pyomo.opt import*
model=ConcreteModel()


model.x1=Var(within=Binary)
model.x2=Var(within=Binary)
model.x3=Var(within=Binary)
model.x4=Var(within=Binary)
model.x5=Var(within=Binary)
model.x6=Var(within=Binary)

model.obj=Objective(expr=300*model.x1+450*model.x2+600*model.x3+150*model.x4+
                    700*model.x5+100*model.x6,sense=minimize)

model.con1=Constraint(expr=model.x1+model.x2>=1)
model.con2=Constraint(expr=model.x1+model.x2+model.x6>=1)
model.con3=Constraint(expr=model.x3+model.x4>=1)
model.con4=Constraint(expr=model.x3+model.x4+model.x5>=1)
model.con5=Constraint(expr=model.x4+model.x5+model.x6>=1)
model.con6=Constraint(expr=model.x2+model.x5+model.x6>=1)


solver=SolverFactory('glpk')
results=solver.solve(model)
print(results)


print('The value of x1 is', value(model.x1))
print('The value of x2 is', value(model.x2))
print('The value of x3 is', value(model.x3))
print('The value of x4 is', value(model.x4))
print('The value of x5 is', value(model.x5))
print('The value of x6 is', value(model.x6))

print("Objective:", value(model.obj))
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 550.0
#   Upper bound: 550.0
#   Number of objectives: 1
#   Number of constraints: 7
#   Number of variables: 7
#   Number of nonzeros: 17
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.042900800704956055
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# The value of x1 is 1.0
# The value of x2 is 0.0
# The value of x3 is 0.0
# The value of x4 is 1.0
# The value of x5 is 0.0
# The value of x6 is 1.0
# Objective: 550.0
